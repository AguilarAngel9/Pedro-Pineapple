# %%
import sys
import torch  
import gym
import numpy as np  
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
import matplotlib.pyplot as plt
import pandas as pd

# %%
# hyperparameters
hidden_size = 256
learning_rate = 3e-4

# Constants
GAMMA = 0.99
num_steps = 300
max_episodes = 3000

# %%
class ActorCritic(nn.Module):
    def __init__(self, num_inputs, num_actions, hidden_size, learning_rate=3e-4):
        super(ActorCritic, self).__init__()

        self.num_actions = num_actions
        self.critic_linear1 = nn.Linear(num_inputs, hidden_size)
        self.critic_linear2 = nn.Linear(hidden_size, 1)

        self.actor_linear1 = nn.Linear(num_inputs, hidden_size)
        self.actor_linear2 = nn.Linear(hidden_size, num_actions)
    
    def forward(self, state):
        state = Variable(torch.from_numpy(state).float().unsqueeze(0))
        value = F.relu(self.critic_linear1(state))
        value = self.critic_linear2(value)
        
        policy_dist = F.relu(self.actor_linear1(state))
        policy_dist = F.softmax(self.actor_linear2(policy_dist), dim=1)

        return value, policy_dist

# %%
def a2c(env):
    num_inputs = env.observation_space.shape[0]
    num_outputs = env.action_space.n
    
    actor_critic = ActorCritic(num_inputs, num_outputs, hidden_size)
    ac_optimizer = optim.Adam(actor_critic.parameters(), lr=learning_rate)

    all_lengths = []
    average_lengths = []
    all_rewards = []
    entropy_term = 0

    for episode in range(max_episodes):
        log_probs = []
        values = []
        rewards = []

        state, info = env.reset()
        for steps in range(num_steps):
            value, policy_dist = actor_critic.forward(state)
            value = value.detach().numpy()[0,0]
            dist = policy_dist.detach().numpy() 

            action = np.random.choice(num_outputs, p=np.squeeze(dist))
            log_prob = torch.log(policy_dist.squeeze(0)[action])
            entropy = -np.sum(np.mean(dist) * np.log(dist))
            new_state, reward, done, truncated, info= env.step(action)

            rewards.append(reward)
            values.append(value)
            log_probs.append(log_prob)
            entropy_term += entropy
            state = new_state
            
            if done or steps == num_steps-1 or truncated:
                Qval, _ = actor_critic.forward(new_state)
                Qval = Qval.detach().numpy()[0,0]
                all_rewards.append(np.sum(rewards))
                all_lengths.append(steps)
                average_lengths.append(np.mean(all_lengths[-10:]))
                if episode % 10 == 0:                    
                    sys.stdout.write("episode: {}, reward: {}, total length: {}, average length: {} \n".format(episode, np.sum(rewards), steps, average_lengths[-1]))
                break
        
        # compute Q values
        Qvals = np.zeros_like(values)
        for t in reversed(range(len(rewards))):
            Qval = rewards[t] + GAMMA * Qval
            Qvals[t] = Qval
  
        #update actor critic
        values = torch.FloatTensor(values)
        Qvals = torch.FloatTensor(Qvals)
        log_probs = torch.stack(log_probs)
        
        advantage = Qvals - values
        actor_loss = (-log_probs * advantage).mean()
        critic_loss = 0.5 * advantage.pow(2).mean()
        ac_loss = actor_loss + critic_loss + 0.001 * entropy_term

        ac_optimizer.zero_grad()
        ac_loss.backward()
        ac_optimizer.step()

        
    
    # Plot results
    smoothed_rewards = pd.Series.rolling(pd.Series(all_rewards), 10).mean()
    smoothed_rewards = [elem for elem in smoothed_rewards]
    plt.plot(all_rewards)
    plt.plot(smoothed_rewards)
    plt.plot()
    plt.xlabel('Episode')
    plt.ylabel('Reward')
    plt.show()

# %%
if __name__ == "__main__":
    env = gym.make("CartPole-v1")
    a2c(env)
# Out:
# C:\Users\DELL\anaconda3\envs\Pineapple\lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# episode: 0, reward: 33.0, total length: 32, average length: 32.0
# episode: 10, reward: 41.0, total length: 40, average length: 32.6
# episode: 20, reward: 10.0, total length: 9, average length: 24.1
# episode: 30, reward: 43.0, total length: 42, average length: 25.3
# episode: 40, reward: 51.0, total length: 50, average length: 28.9
# episode: 50, reward: 17.0, total length: 16, average length: 19.6
# episode: 60, reward: 21.0, total length: 20, average length: 29.0
# episode: 70, reward: 37.0, total length: 36, average length: 35.1
# episode: 80, reward: 19.0, total length: 18, average length: 33.7
# episode: 90, reward: 38.0, total length: 37, average length: 19.9
# episode: 100, reward: 29.0, total length: 28, average length: 32.1
# episode: 110, reward: 15.0, total length: 14, average length: 36.6
# episode: 120, reward: 15.0, total length: 14, average length: 25.5
# episode: 130, reward: 36.0, total length: 35, average length: 25.6
# episode: 140, reward: 29.0, total length: 28, average length: 36.1
# episode: 150, reward: 14.0, total length: 13, average length: 30.9
# episode: 160, reward: 35.0, total length: 34, average length: 28.7
# episode: 170, reward: 32.0, total length: 31, average length: 34.2
# episode: 180, reward: 19.0, total length: 18, average length: 39.2
# episode: 190, reward: 16.0, total length: 15, average length: 33.5
# episode: 200, reward: 16.0, total length: 15, average length: 41.1
# episode: 210, reward: 96.0, total length: 95, average length: 47.8
# episode: 220, reward: 40.0, total length: 39, average length: 36.8
# episode: 230, reward: 38.0, total length: 37, average length: 24.7
# episode: 240, reward: 22.0, total length: 21, average length: 32.8
# episode: 250, reward: 46.0, total length: 45, average length: 40.6
# episode: 260, reward: 46.0, total length: 45, average length: 38.9
# episode: 270, reward: 16.0, total length: 15, average length: 35.1
# episode: 280, reward: 18.0, total length: 17, average length: 32.2
# episode: 290, reward: 49.0, total length: 48, average length: 41.2
# episode: 300, reward: 54.0, total length: 53, average length: 43.7
# episode: 310, reward: 26.0, total length: 25, average length: 38.7
# episode: 320, reward: 47.0, total length: 46, average length: 33.5
# episode: 330, reward: 35.0, total length: 34, average length: 40.9
# episode: 340, reward: 15.0, total length: 14, average length: 47.0
# episode: 350, reward: 17.0, total length: 16, average length: 50.0
# episode: 360, reward: 92.0, total length: 91, average length: 45.4
# episode: 370, reward: 52.0, total length: 51, average length: 34.9
# episode: 380, reward: 52.0, total length: 51, average length: 32.1
# episode: 390, reward: 26.0, total length: 25, average length: 31.9
# episode: 400, reward: 33.0, total length: 32, average length: 39.7
# episode: 410, reward: 26.0, total length: 25, average length: 44.0
# episode: 420, reward: 60.0, total length: 59, average length: 45.5
# episode: 430, reward: 82.0, total length: 81, average length: 48.3
# episode: 440, reward: 41.0, total length: 40, average length: 48.8
# episode: 450, reward: 25.0, total length: 24, average length: 46.9
# episode: 460, reward: 37.0, total length: 36, average length: 32.8
# episode: 470, reward: 19.0, total length: 18, average length: 36.3
# episode: 480, reward: 32.0, total length: 31, average length: 43.8
# episode: 490, reward: 47.0, total length: 46, average length: 51.9
# episode: 500, reward: 30.0, total length: 29, average length: 53.5
# episode: 510, reward: 79.0, total length: 78, average length: 48.9
# episode: 520, reward: 18.0, total length: 17, average length: 43.6
# episode: 530, reward: 119.0, total length: 118, average length: 40.9
# episode: 540, reward: 38.0, total length: 37, average length: 52.1
# episode: 550, reward: 19.0, total length: 18, average length: 42.5
# episode: 560, reward: 40.0, total length: 39, average length: 57.3
# episode: 570, reward: 70.0, total length: 69, average length: 55.1
# episode: 580, reward: 38.0, total length: 37, average length: 42.4
# episode: 590, reward: 31.0, total length: 30, average length: 77.2
# episode: 600, reward: 105.0, total length: 104, average length: 54.8
# episode: 610, reward: 27.0, total length: 26, average length: 55.1
# episode: 620, reward: 30.0, total length: 29, average length: 59.8
# episode: 630, reward: 90.0, total length: 89, average length: 68.9
# episode: 640, reward: 22.0, total length: 21, average length: 78.5
# episode: 650, reward: 38.0, total length: 37, average length: 76.5
# episode: 660, reward: 80.0, total length: 79, average length: 71.2
# episode: 670, reward: 135.0, total length: 134, average length: 91.7
# episode: 680, reward: 168.0, total length: 167, average length: 91.7
# episode: 690, reward: 122.0, total length: 121, average length: 120.8
# episode: 700, reward: 107.0, total length: 106, average length: 87.3
# episode: 710, reward: 43.0, total length: 42, average length: 89.7
# episode: 720, reward: 185.0, total length: 184, average length: 89.2
# episode: 730, reward: 194.0, total length: 193, average length: 87.0
# episode: 740, reward: 53.0, total length: 52, average length: 91.2
# episode: 750, reward: 113.0, total length: 112, average length: 65.5
# episode: 760, reward: 124.0, total length: 123, average length: 91.6
# episode: 770, reward: 52.0, total length: 51, average length: 105.0
# episode: 780, reward: 115.0, total length: 114, average length: 132.5
# episode: 790, reward: 269.0, total length: 268, average length: 140.0
# episode: 800, reward: 90.0, total length: 89, average length: 127.8
# episode: 810, reward: 30.0, total length: 29, average length: 127.1
# episode: 820, reward: 104.0, total length: 103, average length: 146.0
# episode: 830, reward: 170.0, total length: 169, average length: 154.9
# episode: 840, reward: 195.0, total length: 194, average length: 158.4
# episode: 850, reward: 168.0, total length: 167, average length: 151.3
# episode: 860, reward: 172.0, total length: 171, average length: 161.5
# episode: 870, reward: 25.0, total length: 24, average length: 117.5
# episode: 880, reward: 71.0, total length: 70, average length: 125.1
# episode: 890, reward: 242.0, total length: 241, average length: 140.3
# episode: 900, reward: 267.0, total length: 266, average length: 143.3
# episode: 910, reward: 224.0, total length: 223, average length: 138.1
# episode: 920, reward: 165.0, total length: 164, average length: 172.2
# episode: 930, reward: 251.0, total length: 250, average length: 166.1
# episode: 940, reward: 103.0, total length: 102, average length: 164.8
# episode: 950, reward: 182.0, total length: 181, average length: 184.3
# episode: 960, reward: 151.0, total length: 150, average length: 170.0
# episode: 970, reward: 124.0, total length: 123, average length: 204.5
# episode: 980, reward: 172.0, total length: 171, average length: 188.6
# episode: 990, reward: 143.0, total length: 142, average length: 191.0
# episode: 1000, reward: 177.0, total length: 176, average length: 185.0
# episode: 1010, reward: 222.0, total length: 221, average length: 141.5
# episode: 1020, reward: 187.0, total length: 186, average length: 192.6
# episode: 1030, reward: 117.0, total length: 116, average length: 215.8
# episode: 1040, reward: 184.0, total length: 183, average length: 174.8
# episode: 1050, reward: 210.0, total length: 209, average length: 201.4
# episode: 1060, reward: 183.0, total length: 182, average length: 167.6
# episode: 1070, reward: 196.0, total length: 195, average length: 190.4
# episode: 1080, reward: 173.0, total length: 172, average length: 159.9
# episode: 1090, reward: 254.0, total length: 253, average length: 204.5
# episode: 1100, reward: 300.0, total length: 299, average length: 189.2
# episode: 1110, reward: 221.0, total length: 220, average length: 212.4
# episode: 1120, reward: 40.0, total length: 39, average length: 163.6
# episode: 1130, reward: 105.0, total length: 104, average length: 182.4
# episode: 1140, reward: 135.0, total length: 134, average length: 203.4
# episode: 1150, reward: 244.0, total length: 243, average length: 189.9
# episode: 1160, reward: 300.0, total length: 299, average length: 235.0
# episode: 1170, reward: 280.0, total length: 279, average length: 210.7
# episode: 1180, reward: 178.0, total length: 177, average length: 184.0
# episode: 1190, reward: 145.0, total length: 144, average length: 150.8
# episode: 1200, reward: 164.0, total length: 163, average length: 172.3
# episode: 1210, reward: 229.0, total length: 228, average length: 172.9
# episode: 1220, reward: 81.0, total length: 80, average length: 173.0
# episode: 1230, reward: 300.0, total length: 299, average length: 208.3
# episode: 1240, reward: 151.0, total length: 150, average length: 216.3
# episode: 1250, reward: 290.0, total length: 289, average length: 254.9
# episode: 1260, reward: 174.0, total length: 173, average length: 239.1
# episode: 1270, reward: 300.0, total length: 299, average length: 222.2
# episode: 1280, reward: 300.0, total length: 299, average length: 213.3
# episode: 1290, reward: 139.0, total length: 138, average length: 200.4
# episode: 1300, reward: 237.0, total length: 236, average length: 247.8
# episode: 1310, reward: 57.0, total length: 56, average length: 215.4
# episode: 1320, reward: 149.0, total length: 148, average length: 239.4
# episode: 1330, reward: 300.0, total length: 299, average length: 182.7
# episode: 1340, reward: 245.0, total length: 244, average length: 244.9
# episode: 1350, reward: 147.0, total length: 146, average length: 190.2
# episode: 1360, reward: 242.0, total length: 241, average length: 224.6
# episode: 1370, reward: 300.0, total length: 299, average length: 226.0
# episode: 1380, reward: 112.0, total length: 111, average length: 207.8
# episode: 1390, reward: 119.0, total length: 118, average length: 204.9
# episode: 1400, reward: 73.0, total length: 72, average length: 210.1
# episode: 1410, reward: 300.0, total length: 299, average length: 230.0
# episode: 1420, reward: 197.0, total length: 196, average length: 206.1
# episode: 1430, reward: 168.0, total length: 167, average length: 248.1
# episode: 1440, reward: 260.0, total length: 259, average length: 208.9
# episode: 1450, reward: 156.0, total length: 155, average length: 258.7
# episode: 1460, reward: 195.0, total length: 194, average length: 216.2
# episode: 1470, reward: 55.0, total length: 54, average length: 164.9
# episode: 1480, reward: 105.0, total length: 104, average length: 157.4
# episode: 1490, reward: 264.0, total length: 263, average length: 153.9
# episode: 1500, reward: 136.0, total length: 135, average length: 134.7
# episode: 1510, reward: 177.0, total length: 176, average length: 186.1
# episode: 1520, reward: 150.0, total length: 149, average length: 197.7
# episode: 1530, reward: 234.0, total length: 233, average length: 158.3
# episode: 1540, reward: 220.0, total length: 219, average length: 163.4
# episode: 1550, reward: 157.0, total length: 156, average length: 174.3
# episode: 1560, reward: 190.0, total length: 189, average length: 143.6
# episode: 1570, reward: 177.0, total length: 176, average length: 121.3
# episode: 1580, reward: 45.0, total length: 44, average length: 114.0
# episode: 1590, reward: 165.0, total length: 164, average length: 137.7
# episode: 1600, reward: 152.0, total length: 151, average length: 135.5
# episode: 1610, reward: 62.0, total length: 61, average length: 108.4
# episode: 1620, reward: 130.0, total length: 129, average length: 128.7
# episode: 1630, reward: 169.0, total length: 168, average length: 139.3
# episode: 1640, reward: 154.0, total length: 153, average length: 111.4
# episode: 1650, reward: 144.0, total length: 143, average length: 129.8
# episode: 1660, reward: 211.0, total length: 210, average length: 152.8
# episode: 1670, reward: 126.0, total length: 125, average length: 150.0
# episode: 1680, reward: 179.0, total length: 178, average length: 182.9
# episode: 1690, reward: 208.0, total length: 207, average length: 184.2
# episode: 1700, reward: 182.0, total length: 181, average length: 201.3
# episode: 1710, reward: 300.0, total length: 299, average length: 229.1
# episode: 1720, reward: 196.0, total length: 195, average length: 198.3
# episode: 1730, reward: 180.0, total length: 179, average length: 222.4
# episode: 1740, reward: 217.0, total length: 216, average length: 254.8
# episode: 1750, reward: 226.0, total length: 225, average length: 268.0
# episode: 1760, reward: 153.0, total length: 152, average length: 257.2
# episode: 1770, reward: 300.0, total length: 299, average length: 261.2
# episode: 1780, reward: 144.0, total length: 143, average length: 226.2
# episode: 1790, reward: 118.0, total length: 117, average length: 170.7
# episode: 1800, reward: 150.0, total length: 149, average length: 175.7
# episode: 1810, reward: 236.0, total length: 235, average length: 144.4
# episode: 1820, reward: 117.0, total length: 116, average length: 169.6
# episode: 1830, reward: 128.0, total length: 127, average length: 177.7
# episode: 1840, reward: 204.0, total length: 203, average length: 194.5
# episode: 1850, reward: 115.0, total length: 114, average length: 136.9
# episode: 1860, reward: 300.0, total length: 299, average length: 235.5
# episode: 1870, reward: 300.0, total length: 299, average length: 236.2
# episode: 1880, reward: 228.0, total length: 227, average length: 209.5
# episode: 1890, reward: 219.0, total length: 218, average length: 227.7
# episode: 1900, reward: 300.0, total length: 299, average length: 236.2
# episode: 1910, reward: 189.0, total length: 188, average length: 213.1
# episode: 1920, reward: 253.0, total length: 252, average length: 238.8
# episode: 1930, reward: 158.0, total length: 157, average length: 208.1
# episode: 1940, reward: 300.0, total length: 299, average length: 205.3
# episode: 1950, reward: 224.0, total length: 223, average length: 232.7
# episode: 1960, reward: 272.0, total length: 271, average length: 254.2
# episode: 1970, reward: 300.0, total length: 299, average length: 224.8
# episode: 1980, reward: 287.0, total length: 286, average length: 268.5
# episode: 1990, reward: 175.0, total length: 174, average length: 205.1
# episode: 2000, reward: 178.0, total length: 177, average length: 235.9
# episode: 2010, reward: 221.0, total length: 220, average length: 279.0
# episode: 2020, reward: 300.0, total length: 299, average length: 262.9
# episode: 2030, reward: 246.0, total length: 245, average length: 244.2
# episode: 2040, reward: 227.0, total length: 226, average length: 227.9
# episode: 2050, reward: 260.0, total length: 259, average length: 275.5
# episode: 2060, reward: 247.0, total length: 246, average length: 234.1
# episode: 2070, reward: 236.0, total length: 235, average length: 242.9
# episode: 2080, reward: 212.0, total length: 211, average length: 251.6
# episode: 2090, reward: 224.0, total length: 223, average length: 230.4
# episode: 2100, reward: 300.0, total length: 299, average length: 249.1
# episode: 2110, reward: 300.0, total length: 299, average length: 258.6
# episode: 2120, reward: 300.0, total length: 299, average length: 249.0
# episode: 2130, reward: 178.0, total length: 177, average length: 218.2
# episode: 2140, reward: 300.0, total length: 299, average length: 220.5
# episode: 2150, reward: 249.0, total length: 248, average length: 216.1
# episode: 2160, reward: 153.0, total length: 152, average length: 192.6
# episode: 2170, reward: 138.0, total length: 137, average length: 212.3
# episode: 2180, reward: 300.0, total length: 299, average length: 213.0
# episode: 2190, reward: 278.0, total length: 277, average length: 221.4
# episode: 2200, reward: 179.0, total length: 178, average length: 228.4
# episode: 2210, reward: 300.0, total length: 299, average length: 223.2
# episode: 2220, reward: 173.0, total length: 172, average length: 222.0
# episode: 2230, reward: 284.0, total length: 283, average length: 211.6
# episode: 2240, reward: 252.0, total length: 251, average length: 247.0
# episode: 2250, reward: 300.0, total length: 299, average length: 287.9
# episode: 2260, reward: 300.0, total length: 299, average length: 277.3
# episode: 2270, reward: 220.0, total length: 219, average length: 257.7
# episode: 2280, reward: 300.0, total length: 299, average length: 283.6
# episode: 2290, reward: 209.0, total length: 208, average length: 253.7
# episode: 2300, reward: 247.0, total length: 246, average length: 281.7
# episode: 2310, reward: 205.0, total length: 204, average length: 270.0
# episode: 2320, reward: 285.0, total length: 284, average length: 231.7
# episode: 2330, reward: 254.0, total length: 253, average length: 251.6
# episode: 2340, reward: 242.0, total length: 241, average length: 253.4
# episode: 2350, reward: 250.0, total length: 249, average length: 278.6
# episode: 2360, reward: 258.0, total length: 257, average length: 227.0
# episode: 2370, reward: 297.0, total length: 296, average length: 239.7
# episode: 2380, reward: 128.0, total length: 127, average length: 187.9
# episode: 2390, reward: 178.0, total length: 177, average length: 189.4
# episode: 2400, reward: 239.0, total length: 238, average length: 165.3
# episode: 2410, reward: 98.0, total length: 97, average length: 124.1
# episode: 2420, reward: 60.0, total length: 59, average length: 122.9
# episode: 2430, reward: 99.0, total length: 98, average length: 116.6
# episode: 2440, reward: 46.0, total length: 45, average length: 81.5
# episode: 2450, reward: 47.0, total length: 46, average length: 89.8
# episode: 2460, reward: 48.0, total length: 47, average length: 101.4
# episode: 2470, reward: 135.0, total length: 134, average length: 104.8
# episode: 2480, reward: 52.0, total length: 51, average length: 120.0
# episode: 2490, reward: 63.0, total length: 62, average length: 109.5
# episode: 2500, reward: 148.0, total length: 147, average length: 84.6
# episode: 2510, reward: 111.0, total length: 110, average length: 88.8
# episode: 2520, reward: 103.0, total length: 102, average length: 113.5
# episode: 2530, reward: 51.0, total length: 50, average length: 101.9
# episode: 2540, reward: 179.0, total length: 178, average length: 116.9
# episode: 2550, reward: 122.0, total length: 121, average length: 113.4
# episode: 2560, reward: 219.0, total length: 218, average length: 132.8
# episode: 2570, reward: 131.0, total length: 130, average length: 121.4
# episode: 2580, reward: 136.0, total length: 135, average length: 157.2
# episode: 2590, reward: 193.0, total length: 192, average length: 152.3
# episode: 2600, reward: 177.0, total length: 176, average length: 133.1
# episode: 2610, reward: 150.0, total length: 149, average length: 150.1
# episode: 2620, reward: 213.0, total length: 212, average length: 159.6
# episode: 2630, reward: 77.0, total length: 76, average length: 157.2
# episode: 2640, reward: 155.0, total length: 154, average length: 152.5
# episode: 2650, reward: 169.0, total length: 168, average length: 166.3
# episode: 2660, reward: 152.0, total length: 151, average length: 169.1
# episode: 2670, reward: 131.0, total length: 130, average length: 161.4
# episode: 2680, reward: 215.0, total length: 214, average length: 173.6
# episode: 2690, reward: 103.0, total length: 102, average length: 158.5
# episode: 2700, reward: 224.0, total length: 223, average length: 191.9
# episode: 2710, reward: 175.0, total length: 174, average length: 164.8
# episode: 2720, reward: 224.0, total length: 223, average length: 196.3
# episode: 2730, reward: 155.0, total length: 154, average length: 198.3
# episode: 2740, reward: 199.0, total length: 198, average length: 191.0
# episode: 2750, reward: 51.0, total length: 50, average length: 132.0
# episode: 2760, reward: 128.0, total length: 127, average length: 144.6
# episode: 2770, reward: 214.0, total length: 213, average length: 156.3
# episode: 2780, reward: 192.0, total length: 191, average length: 158.4
# episode: 2790, reward: 51.0, total length: 50, average length: 164.5
# episode: 2800, reward: 133.0, total length: 132, average length: 136.0
# episode: 2810, reward: 137.0, total length: 136, average length: 161.8
# episode: 2820, reward: 118.0, total length: 117, average length: 154.4
# episode: 2830, reward: 243.0, total length: 242, average length: 171.2
# episode: 2840, reward: 240.0, total length: 239, average length: 196.6
# episode: 2850, reward: 174.0, total length: 173, average length: 208.2
# episode: 2860, reward: 130.0, total length: 129, average length: 191.5
# episode: 2870, reward: 209.0, total length: 208, average length: 197.1
# episode: 2880, reward: 133.0, total length: 132, average length: 160.8
# episode: 2890, reward: 223.0, total length: 222, average length: 205.2
# episode: 2900, reward: 300.0, total length: 299, average length: 194.2
# episode: 2910, reward: 278.0, total length: 277, average length: 212.4
# episode: 2920, reward: 204.0, total length: 203, average length: 180.2
# episode: 2930, reward: 246.0, total length: 245, average length: 207.3
# episode: 2940, reward: 255.0, total length: 254, average length: 196.3
# episode: 2950, reward: 213.0, total length: 212, average length: 204.0
# episode: 2960, reward: 246.0, total length: 245, average length: 206.7
# episode: 2970, reward: 214.0, total length: 213, average length: 169.4
# episode: 2980, reward: 179.0, total length: 178, average length: 192.7
# episode: 2990, reward: 177.0, total length: 176, average length: 177.8

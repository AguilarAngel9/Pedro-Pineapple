# %%
import sys
import torch  
import gymnasium as gym
import numpy as np  
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
import matplotlib.pyplot as plt
import pandas as pd

# %%
# hyperparameters
hidden_size = 144
learning_rate = 3e-4

# Constants
GAMMA = 0.99
num_steps = 300
max_episodes = 3000

# %%
class ActorCritic(nn.Module):
    def __init__(self, num_inputs, num_actions, hidden_size, learning_rate=3e-4):
        super(ActorCritic, self).__init__()

        self.num_actions = num_actions
        self.critic_linear1 = nn.Linear(num_inputs, hidden_size)
        self.critic_linear2 = nn.Linear(hidden_size, 1)

        self.actor_linear1 = nn.Linear(num_inputs, hidden_size)
        self.actor_linear2 = nn.Linear(hidden_size, num_actions)
    
    def forward(self, state):
        state = Variable(torch.from_numpy(state).float().unsqueeze(0))
        value = F.tanh(self.critic_linear1(state))
        value = self.critic_linear2(value)
        
        policy_dist = F.tanh(self.actor_linear1(state))
        policy_dist = F.softmax(self.actor_linear2(policy_dist), dim=1)

        return value, policy_dist

# %%
def a2c(env):
    num_inputs = env.observation_space.shape[0]
    num_outputs = env.action_space.n
    
    actor_critic = ActorCritic(num_inputs, num_outputs, hidden_size)
    ac_optimizer = optim.Adam(actor_critic.parameters(), lr=learning_rate)

    all_lengths = []
    average_lengths = []
    all_rewards = []
    entropy_term = 0

    for episode in range(max_episodes):
        log_probs = []
        values = []
        rewards = []

        state, info = env.reset()
        for steps in range(num_steps):
            value, policy_dist = actor_critic.forward(state)
            value = value.detach().numpy()[0,0]
            dist = policy_dist.detach().numpy() 

            action = np.random.choice(num_outputs, p=np.squeeze(dist))
            log_prob = torch.log(policy_dist.squeeze(0)[action])
            entropy = -np.sum(np.mean(dist) * np.log(dist))
            new_state, reward, done, truncated, info= env.step(action)

            rewards.append(reward)
            values.append(value)
            log_probs.append(log_prob)
            entropy_term += entropy
            state = new_state
            
            if done or steps == num_steps-1 or truncated:
                Qval, _ = actor_critic.forward(new_state)
                Qval = Qval.detach().numpy()[0,0]
                all_rewards.append(np.sum(rewards))
                all_lengths.append(steps)
                average_lengths.append(np.mean(all_lengths[-10:]))
                if episode % 50 == 0:                    
                    sys.stdout.write("episode: {}, reward: {}, total length: {}, average length: {} \n".format(episode, np.sum(rewards), steps, average_lengths[-1]))
                break
        
        # compute Q values
        Qvals = np.zeros_like(values)
        for t in reversed(range(len(rewards))):
            Qval = rewards[t] + GAMMA * Qval
            Qvals[t] = Qval
  
        #update actor critic
        values = torch.FloatTensor(values)
        Qvals = torch.FloatTensor(Qvals)
        log_probs = torch.stack(log_probs)
        
        advantage = Qvals - values
        actor_loss = (-log_probs * advantage).mean()
        critic_loss = 0.5 * advantage.pow(2).mean()
        ac_loss = actor_loss + critic_loss + 0.001 * entropy_term

        ac_optimizer.zero_grad()
        ac_loss.backward()
        ac_optimizer.step()

        
    
    # Plot results
    smoothed_rewards = pd.Series.rolling(pd.Series(all_rewards), 10).mean()
    smoothed_rewards = [elem for elem in smoothed_rewards]
    plt.plot(all_rewards)
    plt.plot(smoothed_rewards)
    plt.plot()
    plt.xlabel('Episode')
    plt.ylabel('Reward')
    plt.show()

# %%
if __name__ == "__main__":
    env = gym.make("CartPole-v1")
    a2c(env)
# Out:
# episode: 0, reward: 18.0, total length: 17, average length: 17.0
# episode: 50, reward: 31.0, total length: 30, average length: 20.3
# episode: 100, reward: 42.0, total length: 41, average length: 23.2
# episode: 150, reward: 46.0, total length: 45, average length: 26.4
# episode: 200, reward: 28.0, total length: 27, average length: 27.7
# episode: 250, reward: 36.0, total length: 35, average length: 33.4
# episode: 300, reward: 16.0, total length: 15, average length: 34.8
# episode: 350, reward: 103.0, total length: 102, average length: 47.1
# episode: 400, reward: 31.0, total length: 30, average length: 78.9
# episode: 450, reward: 64.0, total length: 63, average length: 61.2
# episode: 500, reward: 16.0, total length: 15, average length: 54.3
# episode: 550, reward: 94.0, total length: 93, average length: 54.7
# episode: 600, reward: 55.0, total length: 54, average length: 69.7
# episode: 650, reward: 50.0, total length: 49, average length: 88.0
# episode: 700, reward: 125.0, total length: 124, average length: 87.3
# episode: 750, reward: 58.0, total length: 57, average length: 77.1
# episode: 800, reward: 119.0, total length: 118, average length: 100.1
# episode: 850, reward: 172.0, total length: 171, average length: 129.7
# episode: 900, reward: 146.0, total length: 145, average length: 160.0
# episode: 950, reward: 131.0, total length: 130, average length: 152.2
# episode: 1000, reward: 95.0, total length: 94, average length: 145.4
# episode: 1050, reward: 220.0, total length: 219, average length: 170.7
# episode: 1100, reward: 147.0, total length: 146, average length: 136.4
# episode: 1150, reward: 163.0, total length: 162, average length: 162.7
# episode: 1200, reward: 28.0, total length: 27, average length: 165.2
# episode: 1250, reward: 300.0, total length: 299, average length: 183.2
# episode: 1300, reward: 169.0, total length: 168, average length: 152.4
# episode: 1350, reward: 201.0, total length: 200, average length: 159.8
# episode: 1400, reward: 61.0, total length: 60, average length: 184.2
# episode: 1450, reward: 225.0, total length: 224, average length: 159.2
# episode: 1500, reward: 180.0, total length: 179, average length: 136.3
# episode: 1550, reward: 300.0, total length: 299, average length: 143.9
# episode: 1600, reward: 43.0, total length: 42, average length: 83.6
# episode: 1650, reward: 281.0, total length: 280, average length: 117.2
# episode: 1700, reward: 142.0, total length: 141, average length: 118.6
# episode: 1750, reward: 224.0, total length: 223, average length: 134.1
# episode: 1800, reward: 129.0, total length: 128, average length: 169.1
# episode: 1850, reward: 107.0, total length: 106, average length: 180.0
# episode: 1900, reward: 246.0, total length: 245, average length: 203.9
# episode: 1950, reward: 115.0, total length: 114, average length: 223.4
# episode: 2000, reward: 124.0, total length: 123, average length: 202.6
# episode: 2050, reward: 265.0, total length: 264, average length: 161.3
# episode: 2100, reward: 18.0, total length: 17, average length: 127.3
# episode: 2150, reward: 124.0, total length: 123, average length: 184.2
# episode: 2200, reward: 41.0, total length: 40, average length: 137.1
# episode: 2250, reward: 191.0, total length: 190, average length: 125.0
# episode: 2300, reward: 178.0, total length: 177, average length: 122.0
# episode: 2350, reward: 151.0, total length: 150, average length: 126.9
# episode: 2400, reward: 141.0, total length: 140, average length: 144.6
# episode: 2450, reward: 205.0, total length: 204, average length: 165.7
# episode: 2500, reward: 144.0, total length: 143, average length: 162.7
# episode: 2550, reward: 200.0, total length: 199, average length: 196.4
# episode: 2600, reward: 119.0, total length: 118, average length: 240.0
# episode: 2650, reward: 216.0, total length: 215, average length: 174.9
# episode: 2700, reward: 300.0, total length: 299, average length: 258.5
# episode: 2750, reward: 230.0, total length: 229, average length: 246.8
# episode: 2800, reward: 300.0, total length: 299, average length: 205.3
# episode: 2850, reward: 257.0, total length: 256, average length: 220.0
# episode: 2900, reward: 54.0, total length: 53, average length: 126.9
# episode: 2950, reward: 107.0, total length: 106, average length: 114.7
